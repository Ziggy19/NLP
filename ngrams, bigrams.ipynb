# %% [markdown]
# # Tokenizations

# %%
import nltk
paragraph=  """Speech on APJ Abdul Kalam: Dr. APJ Abdul Kalam is not a new name.
            He served India as the 11th president. He was born on 15 October 1931 in Rameswaram, Tamil Nadu.
            Because of his works in the field of science and especially missile and rockets,
            he is also called the Missile Man of India. He was a famous scientist. 
            He worked with organizations like DRDO (Defense Research and Development Organization)
            and ISRO (Indian Space Research Organization).
            He was a real gem of India. He proved that with determination and hard work anything can be achieved.
            He is one of the many leaders in India who has plenty of admirers. 
            He served the nation for only one term and left us for always on 27 July 2015 due to cardiac arrest.
            """

# %%
from nltk.util import bigrams, trigrams, ngrams
word= nltk.word_tokenize(paragraph)
sentence=nltk.sent_tokenize(paragraph)

# %%
string_bigrams = list(nltk.bigrams(word))
string_bigrams
# Out:
# [('Speech', 'on'),
#  ('on', 'APJ'),
#  ('APJ', 'Abdul'),
#  ('Abdul', 'Kalam'),
#  ('Kalam', ':'),
#  (':', 'Dr.'),
#  ('Dr.', 'APJ'),
#  ('APJ', 'Abdul'),
#  ('Abdul', 'Kalam'),
#  ('Kalam', 'is'),
#  ('is', 'not'),
#  ('not', 'a'),
#  ('a', 'new'),
#  ('new', 'name'),
#  ('name', '.'),
#  ('.', 'He'),
#  ('He', 'served'),
#  ('served', 'India'),
#  ('India', 'as'),
#  ('as', 'the'),
#  ('the', '11th'),
#  ('11th', 'president'),
#  ('president', '.'),
#  ('.', 'He'),
#  ('He', 'was'),
#  ('was', 'born'),
#  ('born', 'on'),
#  ('on', '15'),
#  ('15', 'October'),
#  ('October', '1931'),
#  ('1931', 'in'),
#  ('in', 'Rameswaram'),
#  ('Rameswaram', ','),
#  (',', 'Tamil'),
#  ('Tamil', 'Nadu'),
#  ('Nadu', '.'),
#  ('.', 'Because'),
#  ('Because', 'of'),
#  ('of', 'his'),
#  ('his', 'works'),
#  ('works', 'in'),
#  ('in', 'the'),
#  ('the', 'field'),
#  ('field', 'of'),
#  ('of', 'science'),
#  ('science', 'and'),
#  ('and', 'especially'),
#  ('especially', 'missile'),
#  ('missile', 'and'),
#  ('and', 'rockets'),
#  ('rockets', ','),
#  (',', 'he'),
#  ('he', 'is'),
#  ('is', 'also'),
#  ('also', 'called'),
#  ('called', 'the'),
#  ('the', 'Missile'),
#  ('Missile', 'Man'),
#  ('Man', 'of'),
#  ('of', 'India'),
#  ('India', '.'),
#  ('.', 'He'),
#  ('He', 'was'),
#  ('was', 'a'),
#  ('a', 'famous'),
#  ('famous', 'scientist'),
#  ('scientist', '.'),
#  ('.', 'He'),
#  ('He', 'worked'),
#  ('worked', 'with'),
#  ('with', 'organizations'),
#  ('organizations', 'like'),
#  ('like', 'DRDO'),
#  ('DRDO', '('),
#  ('(', 'Defense'),
#  ('Defense', 'Research'),
#  ('Research', 'and'),
#  ('and', 'Development'),
#  ('Development', 'Organization'),
#  ('Organization', ')'),
#  (')', 'and'),
#  ('and', 'ISRO'),
#  ('ISRO', '('),
#  ('(', 'Indian'),
#  ('Indian', 'Space'),
#  ('Space', 'Research'),
#  ('Research', 'Organization'),
#  ('Organization', ')'),
#  (')', '.'),
#  ('.', 'He'),
#  ('He', 'was'),
#  ('was', 'a'),
#  ('a', 'real'),
#  ('real', 'gem'),
#  ('gem', 'of'),
#  ('of', 'India'),
#  ('India', '.'),
#  ('.', 'He'),
#  ('He', 'proved'),
#  ('proved', 'that'),
#  ('that', 'with'),
#  ('with', 'determination'),
#  ('determination', 'and'),
#  ('and', 'hard'),
#  ('hard', 'work'),
#  ('work', 'anything'),
#  ('anything', 'can'),
#  ('can', 'be'),
#  ('be', 'achieved'),
#  ('achieved', '.'),
#  ('.', 'He'),
#  ('He', 'is'),
#  ('is', 'one'),
#  ('one', 'of'),
#  ('of', 'the'),
#  ('the', 'many'),
#  ('many', 'leaders'),
#  ('leaders', 'in'),
#  ('in', 'India'),
#  ('India', 'who'),
#  ('who', 'has'),
#  ('has', 'plenty'),
#  ('plenty', 'of'),
#  ('of', 'admirers'),
#  ('admirers', '.'),
#  ('.', 'He'),
#  ('He', 'served'),
#  ('served', 'the'),
#  ('the', 'nation'),
#  ('nation', 'for'),
#  ('for', 'only'),
#  ('only', 'one'),
#  ('one', 'term'),
#  ('term', 'and'),
#  ('and', 'left'),
#  ('left', 'us'),
#  ('us', 'for'),
#  ('for', 'always'),
#  ('always', 'on'),
#  ('on', '27'),
#  ('27', 'July'),
#  ('July', '2015'),
#  ('2015', 'due'),
#  ('due', 'to'),
#  ('to', 'cardiac'),
#  ('cardiac', 'arrest'),
#  ('arrest', '.')]

# %%
string_bigrams = list(nltk.trigrams(word))
string_bigrams
# Out:
# [('Speech', 'on', 'APJ'),
#  ('on', 'APJ', 'Abdul'),
#  ('APJ', 'Abdul', 'Kalam'),
#  ('Abdul', 'Kalam', ':'),
#  ('Kalam', ':', 'Dr.'),
#  (':', 'Dr.', 'APJ'),
#  ('Dr.', 'APJ', 'Abdul'),
#  ('APJ', 'Abdul', 'Kalam'),
#  ('Abdul', 'Kalam', 'is'),
#  ('Kalam', 'is', 'not'),
#  ('is', 'not', 'a'),
#  ('not', 'a', 'new'),
#  ('a', 'new', 'name'),
#  ('new', 'name', '.'),
#  ('name', '.', 'He'),
#  ('.', 'He', 'served'),
#  ('He', 'served', 'India'),
#  ('served', 'India', 'as'),
#  ('India', 'as', 'the'),
#  ('as', 'the', '11th'),
#  ('the', '11th', 'president'),
#  ('11th', 'president', '.'),
#  ('president', '.', 'He'),
#  ('.', 'He', 'was'),
#  ('He', 'was', 'born'),
#  ('was', 'born', 'on'),
#  ('born', 'on', '15'),
#  ('on', '15', 'October'),
#  ('15', 'October', '1931'),
#  ('October', '1931', 'in'),
#  ('1931', 'in', 'Rameswaram'),
#  ('in', 'Rameswaram', ','),
#  ('Rameswaram', ',', 'Tamil'),
#  (',', 'Tamil', 'Nadu'),
#  ('Tamil', 'Nadu', '.'),
#  ('Nadu', '.', 'Because'),
#  ('.', 'Because', 'of'),
#  ('Because', 'of', 'his'),
#  ('of', 'his', 'works'),
#  ('his', 'works', 'in'),
#  ('works', 'in', 'the'),
#  ('in', 'the', 'field'),
#  ('the', 'field', 'of'),
#  ('field', 'of', 'science'),
#  ('of', 'science', 'and'),
#  ('science', 'and', 'especially'),
#  ('and', 'especially', 'missile'),
#  ('especially', 'missile', 'and'),
#  ('missile', 'and', 'rockets'),
#  ('and', 'rockets', ','),
#  ('rockets', ',', 'he'),
#  (',', 'he', 'is'),
#  ('he', 'is', 'also'),
#  ('is', 'also', 'called'),
#  ('also', 'called', 'the'),
#  ('called', 'the', 'Missile'),
#  ('the', 'Missile', 'Man'),
#  ('Missile', 'Man', 'of'),
#  ('Man', 'of', 'India'),
#  ('of', 'India', '.'),
#  ('India', '.', 'He'),
#  ('.', 'He', 'was'),
#  ('He', 'was', 'a'),
#  ('was', 'a', 'famous'),
#  ('a', 'famous', 'scientist'),
#  ('famous', 'scientist', '.'),
#  ('scientist', '.', 'He'),
#  ('.', 'He', 'worked'),
#  ('He', 'worked', 'with'),
#  ('worked', 'with', 'organizations'),
#  ('with', 'organizations', 'like'),
#  ('organizations', 'like', 'DRDO'),
#  ('like', 'DRDO', '('),
#  ('DRDO', '(', 'Defense'),
#  ('(', 'Defense', 'Research'),
#  ('Defense', 'Research', 'and'),
#  ('Research', 'and', 'Development'),
#  ('and', 'Development', 'Organization'),
#  ('Development', 'Organization', ')'),
#  ('Organization', ')', 'and'),
#  (')', 'and', 'ISRO'),
#  ('and', 'ISRO', '('),
#  ('ISRO', '(', 'Indian'),
#  ('(', 'Indian', 'Space'),
#  ('Indian', 'Space', 'Research'),
#  ('Space', 'Research', 'Organization'),
#  ('Research', 'Organization', ')'),
#  ('Organization', ')', '.'),
#  (')', '.', 'He'),
#  ('.', 'He', 'was'),
#  ('He', 'was', 'a'),
#  ('was', 'a', 'real'),
#  ('a', 'real', 'gem'),
#  ('real', 'gem', 'of'),
#  ('gem', 'of', 'India'),
#  ('of', 'India', '.'),
#  ('India', '.', 'He'),
#  ('.', 'He', 'proved'),
#  ('He', 'proved', 'that'),
#  ('proved', 'that', 'with'),
#  ('that', 'with', 'determination'),
#  ('with', 'determination', 'and'),
#  ('determination', 'and', 'hard'),
#  ('and', 'hard', 'work'),
#  ('hard', 'work', 'anything'),
#  ('work', 'anything', 'can'),
#  ('anything', 'can', 'be'),
#  ('can', 'be', 'achieved'),
#  ('be', 'achieved', '.'),
#  ('achieved', '.', 'He'),
#  ('.', 'He', 'is'),
#  ('He', 'is', 'one'),
#  ('is', 'one', 'of'),
#  ('one', 'of', 'the'),
#  ('of', 'the', 'many'),
#  ('the', 'many', 'leaders'),
#  ('many', 'leaders', 'in'),
#  ('leaders', 'in', 'India'),
#  ('in', 'India', 'who'),
#  ('India', 'who', 'has'),
#  ('who', 'has', 'plenty'),
#  ('has', 'plenty', 'of'),
#  ('plenty', 'of', 'admirers'),
#  ('of', 'admirers', '.'),
#  ('admirers', '.', 'He'),
#  ('.', 'He', 'served'),
#  ('He', 'served', 'the'),
#  ('served', 'the', 'nation'),
#  ('the', 'nation', 'for'),
#  ('nation', 'for', 'only'),
#  ('for', 'only', 'one'),
#  ('only', 'one', 'term'),
#  ('one', 'term', 'and'),
#  ('term', 'and', 'left'),
#  ('and', 'left', 'us'),
#  ('left', 'us', 'for'),
#  ('us', 'for', 'always'),
#  ('for', 'always', 'on'),
#  ('always', 'on', '27'),
#  ('on', '27', 'July'),
#  ('27', 'July', '2015'),
#  ('July', '2015', 'due'),
#  ('2015', 'due', 'to'),
#  ('due', 'to', 'cardiac'),
#  ('to', 'cardiac', 'arrest'),
#  ('cardiac', 'arrest', '.')]

# %%
string_bigrams = list(nltk.ngrams(word,5))
string_bigrams
# Out:
# [('Speech', 'on', 'APJ', 'Abdul', 'Kalam'),
#  ('on', 'APJ', 'Abdul', 'Kalam', ':'),
#  ('APJ', 'Abdul', 'Kalam', ':', 'Dr.'),
#  ('Abdul', 'Kalam', ':', 'Dr.', 'APJ'),
#  ('Kalam', ':', 'Dr.', 'APJ', 'Abdul'),
#  (':', 'Dr.', 'APJ', 'Abdul', 'Kalam'),
#  ('Dr.', 'APJ', 'Abdul', 'Kalam', 'is'),
#  ('APJ', 'Abdul', 'Kalam', 'is', 'not'),
#  ('Abdul', 'Kalam', 'is', 'not', 'a'),
#  ('Kalam', 'is', 'not', 'a', 'new'),
#  ('is', 'not', 'a', 'new', 'name'),
#  ('not', 'a', 'new', 'name', '.'),
#  ('a', 'new', 'name', '.', 'He'),
#  ('new', 'name', '.', 'He', 'served'),
#  ('name', '.', 'He', 'served', 'India'),
#  ('.', 'He', 'served', 'India', 'as'),
#  ('He', 'served', 'India', 'as', 'the'),
#  ('served', 'India', 'as', 'the', '11th'),
#  ('India', 'as', 'the', '11th', 'president'),
#  ('as', 'the', '11th', 'president', '.'),
#  ('the', '11th', 'president', '.', 'He'),
#  ('11th', 'president', '.', 'He', 'was'),
#  ('president', '.', 'He', 'was', 'born'),
#  ('.', 'He', 'was', 'born', 'on'),
#  ('He', 'was', 'born', 'on', '15'),
#  ('was', 'born', 'on', '15', 'October'),
#  ('born', 'on', '15', 'October', '1931'),
#  ('on', '15', 'October', '1931', 'in'),
#  ('15', 'October', '1931', 'in', 'Rameswaram'),
#  ('October', '1931', 'in', 'Rameswaram', ','),
#  ('1931', 'in', 'Rameswaram', ',', 'Tamil'),
#  ('in', 'Rameswaram', ',', 'Tamil', 'Nadu'),
#  ('Rameswaram', ',', 'Tamil', 'Nadu', '.'),
#  (',', 'Tamil', 'Nadu', '.', 'Because'),
#  ('Tamil', 'Nadu', '.', 'Because', 'of'),
#  ('Nadu', '.', 'Because', 'of', 'his'),
#  ('.', 'Because', 'of', 'his', 'works'),
#  ('Because', 'of', 'his', 'works', 'in'),
#  ('of', 'his', 'works', 'in', 'the'),
#  ('his', 'works', 'in', 'the', 'field'),
#  ('works', 'in', 'the', 'field', 'of'),
#  ('in', 'the', 'field', 'of', 'science'),
#  ('the', 'field', 'of', 'science', 'and'),
#  ('field', 'of', 'science', 'and', 'especially'),
#  ('of', 'science', 'and', 'especially', 'missile'),
#  ('science', 'and', 'especially', 'missile', 'and'),
#  ('and', 'especially', 'missile', 'and', 'rockets'),
#  ('especially', 'missile', 'and', 'rockets', ','),
#  ('missile', 'and', 'rockets', ',', 'he'),
#  ('and', 'rockets', ',', 'he', 'is'),
#  ('rockets', ',', 'he', 'is', 'also'),
#  (',', 'he', 'is', 'also', 'called'),
#  ('he', 'is', 'also', 'called', 'the'),
#  ('is', 'also', 'called', 'the', 'Missile'),
#  ('also', 'called', 'the', 'Missile', 'Man'),
#  ('called', 'the', 'Missile', 'Man', 'of'),
#  ('the', 'Missile', 'Man', 'of', 'India'),
#  ('Missile', 'Man', 'of', 'India', '.'),
#  ('Man', 'of', 'India', '.', 'He'),
#  ('of', 'India', '.', 'He', 'was'),
#  ('India', '.', 'He', 'was', 'a'),
#  ('.', 'He', 'was', 'a', 'famous'),
#  ('He', 'was', 'a', 'famous', 'scientist'),
#  ('was', 'a', 'famous', 'scientist', '.'),
#  ('a', 'famous', 'scientist', '.', 'He'),
#  ('famous', 'scientist', '.', 'He', 'worked'),
#  ('scientist', '.', 'He', 'worked', 'with'),
#  ('.', 'He', 'worked', 'with', 'organizations'),
#  ('He', 'worked', 'with', 'organizations', 'like'),
#  ('worked', 'with', 'organizations', 'like', 'DRDO'),
#  ('with', 'organizations', 'like', 'DRDO', '('),
#  ('organizations', 'like', 'DRDO', '(', 'Defense'),
#  ('like', 'DRDO', '(', 'Defense', 'Research'),
#  ('DRDO', '(', 'Defense', 'Research', 'and'),
#  ('(', 'Defense', 'Research', 'and', 'Development'),
#  ('Defense', 'Research', 'and', 'Development', 'Organization'),
#  ('Research', 'and', 'Development', 'Organization', ')'),
#  ('and', 'Development', 'Organization', ')', 'and'),
#  ('Development', 'Organization', ')', 'and', 'ISRO'),
#  ('Organization', ')', 'and', 'ISRO', '('),
#  (')', 'and', 'ISRO', '(', 'Indian'),
#  ('and', 'ISRO', '(', 'Indian', 'Space'),
#  ('ISRO', '(', 'Indian', 'Space', 'Research'),
#  ('(', 'Indian', 'Space', 'Research', 'Organization'),
#  ('Indian', 'Space', 'Research', 'Organization', ')'),
#  ('Space', 'Research', 'Organization', ')', '.'),
#  ('Research', 'Organization', ')', '.', 'He'),
#  ('Organization', ')', '.', 'He', 'was'),
#  (')', '.', 'He', 'was', 'a'),
#  ('.', 'He', 'was', 'a', 'real'),
#  ('He', 'was', 'a', 'real', 'gem'),
#  ('was', 'a', 'real', 'gem', 'of'),
#  ('a', 'real', 'gem', 'of', 'India'),
#  ('real', 'gem', 'of', 'India', '.'),
#  ('gem', 'of', 'India', '.', 'He'),
#  ('of', 'India', '.', 'He', 'proved'),
#  ('India', '.', 'He', 'proved', 'that'),
#  ('.', 'He', 'proved', 'that', 'with'),
#  ('He', 'proved', 'that', 'with', 'determination'),
#  ('proved', 'that', 'with', 'determination', 'and'),
#  ('that', 'with', 'determination', 'and', 'hard'),
#  ('with', 'determination', 'and', 'hard', 'work'),
#  ('determination', 'and', 'hard', 'work', 'anything'),
#  ('and', 'hard', 'work', 'anything', 'can'),
#  ('hard', 'work', 'anything', 'can', 'be'),
#  ('work', 'anything', 'can', 'be', 'achieved'),
#  ('anything', 'can', 'be', 'achieved', '.'),
#  ('can', 'be', 'achieved', '.', 'He'),
#  ('be', 'achieved', '.', 'He', 'is'),
#  ('achieved', '.', 'He', 'is', 'one'),
#  ('.', 'He', 'is', 'one', 'of'),
#  ('He', 'is', 'one', 'of', 'the'),
#  ('is', 'one', 'of', 'the', 'many'),
#  ('one', 'of', 'the', 'many', 'leaders'),
#  ('of', 'the', 'many', 'leaders', 'in'),
#  ('the', 'many', 'leaders', 'in', 'India'),
#  ('many', 'leaders', 'in', 'India', 'who'),
#  ('leaders', 'in', 'India', 'who', 'has'),
#  ('in', 'India', 'who', 'has', 'plenty'),
#  ('India', 'who', 'has', 'plenty', 'of'),
#  ('who', 'has', 'plenty', 'of', 'admirers'),
#  ('has', 'plenty', 'of', 'admirers', '.'),
#  ('plenty', 'of', 'admirers', '.', 'He'),
#  ('of', 'admirers', '.', 'He', 'served'),
#  ('admirers', '.', 'He', 'served', 'the'),
#  ('.', 'He', 'served', 'the', 'nation'),
#  ('He', 'served', 'the', 'nation', 'for'),
#  ('served', 'the', 'nation', 'for', 'only'),
#  ('the', 'nation', 'for', 'only', 'one'),
#  ('nation', 'for', 'only', 'one', 'term'),
#  ('for', 'only', 'one', 'term', 'and'),
#  ('only', 'one', 'term', 'and', 'left'),
#  ('one', 'term', 'and', 'left', 'us'),
#  ('term', 'and', 'left', 'us', 'for'),
#  ('and', 'left', 'us', 'for', 'always'),
#  ('left', 'us', 'for', 'always', 'on'),
#  ('us', 'for', 'always', 'on', '27'),
#  ('for', 'always', 'on', '27', 'July'),
#  ('always', 'on', '27', 'July', '2015'),
#  ('on', '27', 'July', '2015', 'due'),
#  ('27', 'July', '2015', 'due', 'to'),
#  ('July', '2015', 'due', 'to', 'cardiac'),
#  ('2015', 'due', 'to', 'cardiac', 'arrest'),
#  ('due', 'to', 'cardiac', 'arrest', '.')]

# %%
string_bigrams = list(nltk.ngrams(word,10))
string_bigrams
# Out:
# [('Speech',
#   'on',
#   'APJ',
#   'Abdul',
#   'Kalam',
#   ':',
#   'Dr.',
#   'APJ',
#   'Abdul',
#   'Kalam'),
#  ('on', 'APJ', 'Abdul', 'Kalam', ':', 'Dr.', 'APJ', 'Abdul', 'Kalam', 'is'),
#  ('APJ', 'Abdul', 'Kalam', ':', 'Dr.', 'APJ', 'Abdul', 'Kalam', 'is', 'not'),
#  ('Abdul', 'Kalam', ':', 'Dr.', 'APJ', 'Abdul', 'Kalam', 'is', 'not', 'a'),
#  ('Kalam', ':', 'Dr.', 'APJ', 'Abdul', 'Kalam', 'is', 'not', 'a', 'new'),
#  (':', 'Dr.', 'APJ', 'Abdul', 'Kalam', 'is', 'not', 'a', 'new', 'name'),
#  ('Dr.', 'APJ', 'Abdul', 'Kalam', 'is', 'not', 'a', 'new', 'name', '.'),
#  ('APJ', 'Abdul', 'Kalam', 'is', 'not', 'a', 'new', 'name', '.', 'He'),
#  ('Abdul', 'Kalam', 'is', 'not', 'a', 'new', 'name', '.', 'He', 'served'),
#  ('Kalam', 'is', 'not', 'a', 'new', 'name', '.', 'He', 'served', 'India'),
#  ('is', 'not', 'a', 'new', 'name', '.', 'He', 'served', 'India', 'as'),
#  ('not', 'a', 'new', 'name', '.', 'He', 'served', 'India', 'as', 'the'),
#  ('a', 'new', 'name', '.', 'He', 'served', 'India', 'as', 'the', '11th'),
#  ('new',
#   'name',
#   '.',
#   'He',
#   'served',
#   'India',
#   'as',
#   'the',
#   '11th',
#   'president'),
#  ('name', '.', 'He', 'served', 'India', 'as', 'the', '11th', 'president', '.'),
#  ('.', 'He', 'served', 'India', 'as', 'the', '11th', 'president', '.', 'He'),
#  ('He', 'served', 'India', 'as', 'the', '11th', 'president', '.', 'He', 'was'),
#  ('served',
#   'India',
#   'as',
#   'the',
#   '11th',
#   'president',
#   '.',
#   'He',
#   'was',
#   'born'),
#  ('India', 'as', 'the', '11th', 'president', '.', 'He', 'was', 'born', 'on'),
#  ('as', 'the', '11th', 'president', '.', 'He', 'was', 'born', 'on', '15'),
#  ('the', '11th', 'president', '.', 'He', 'was', 'born', 'on', '15', 'October'),
#  ('11th',
#   'president',
#   '.',
#   'He',
#   'was',
#   'born',
#   'on',
#   '15',
#   'October',
#   '1931'),
#  ('president', '.', 'He', 'was', 'born', 'on', '15', 'October', '1931', 'in'),
#  ('.', 'He', 'was', 'born', 'on', '15', 'October', '1931', 'in', 'Rameswaram'),
#  ('He', 'was', 'born', 'on', '15', 'October', '1931', 'in', 'Rameswaram', ','),
#  ('was',
#   'born',
#   'on',
#   '15',
#   'October',
#   '1931',
#   'in',
#   'Rameswaram',
#   ',',
#   'Tamil'),
#  ('born',
#   'on',
#   '15',
#   'October',
#   '1931',
#   'in',
#   'Rameswaram',
#   ',',
#   'Tamil',
#   'Nadu'),
#  ('on',
#   '15',
#   'October',
#   '1931',
#   'in',
#   'Rameswaram',
#   ',',
#   'Tamil',
#   'Nadu',
#   '.'),
#  ('15',
#   'October',
#   '1931',
#   'in',
#   'Rameswaram',
#   ',',
#   'Tamil',
#   'Nadu',
#   '.',
#   'Because'),
#  ('October',
#   '1931',
#   'in',
#   'Rameswaram',
#   ',',
#   'Tamil',
#   'Nadu',
#   '.',
#   'Because',
#   'of'),
#  ('1931',
#   'in',
#   'Rameswaram',
#   ',',
#   'Tamil',
#   'Nadu',
#   '.',
#   'Because',
#   'of',
#   'his'),
#  ('in',
#   'Rameswaram',
#   ',',
#   'Tamil',
#   'Nadu',
#   '.',
#   'Because',
#   'of',
#   'his',
#   'works'),
#  ('Rameswaram',
#   ',',
#   'Tamil',
#   'Nadu',
#   '.',
#   'Because',
#   'of',
#   'his',
#   'works',
#   'in'),
#  (',', 'Tamil', 'Nadu', '.', 'Because', 'of', 'his', 'works', 'in', 'the'),
#  ('Tamil', 'Nadu', '.', 'Because', 'of', 'his', 'works', 'in', 'the', 'field'),
#  ('Nadu', '.', 'Because', 'of', 'his', 'works', 'in', 'the', 'field', 'of'),
#  ('.', 'Because', 'of', 'his', 'works', 'in', 'the', 'field', 'of', 'science'),
#  ('Because',
#   'of',
#   'his',
#   'works',
#   'in',
#   'the',
#   'field',
#   'of',
#   'science',
#   'and'),
#  ('of',
#   'his',
#   'works',
#   'in',
#   'the',
#   'field',
#   'of',
#   'science',
#   'and',
#   'especially'),
#  ('his',
#   'works',
#   'in',
#   'the',
#   'field',
#   'of',
#   'science',
#   'and',
#   'especially',
#   'missile'),
#  ('works',
#   'in',
#   'the',
#   'field',
#   'of',
#   'science',
#   'and',
#   'especially',
#   'missile',
#   'and'),
#  ('in',
#   'the',
#   'field',
#   'of',
#   'science',
#   'and',
#   'especially',
#   'missile',
#   'and',
#   'rockets'),
#  ('the',
#   'field',
#   'of',
#   'science',
#   'and',
#   'especially',
#   'missile',
#   'and',
#   'rockets',
#   ','),
#  ('field',
#   'of',
#   'science',
#   'and',
#   'especially',
#   'missile',
#   'and',
#   'rockets',
#   ',',
#   'he'),
#  ('of',
#   'science',
#   'and',
#   'especially',
#   'missile',
#   'and',
#   'rockets',
#   ',',
#   'he',
#   'is'),
#  ('science',
#   'and',
#   'especially',
#   'missile',
#   'and',
#   'rockets',
#   ',',
#   'he',
#   'is',
#   'also'),
#  ('and',
#   'especially',
#   'missile',
#   'and',
#   'rockets',
#   ',',
#   'he',
#   'is',
#   'also',
#   'called'),
#  ('especially',
#   'missile',
#   'and',
#   'rockets',
#   ',',
#   'he',
#   'is',
#   'also',
#   'called',
#   'the'),
#  ('missile',
#   'and',
#   'rockets',
#   ',',
#   'he',
#   'is',
#   'also',
#   'called',
#   'the',
#   'Missile'),
#  ('and',
#   'rockets',
#   ',',
#   'he',
#   'is',
#   'also',
#   'called',
#   'the',
#   'Missile',
#   'Man'),
#  ('rockets', ',', 'he', 'is', 'also', 'called', 'the', 'Missile', 'Man', 'of'),
#  (',', 'he', 'is', 'also', 'called', 'the', 'Missile', 'Man', 'of', 'India'),
#  ('he', 'is', 'also', 'called', 'the', 'Missile', 'Man', 'of', 'India', '.'),
#  ('is', 'also', 'called', 'the', 'Missile', 'Man', 'of', 'India', '.', 'He'),
#  ('also', 'called', 'the', 'Missile', 'Man', 'of', 'India', '.', 'He', 'was'),
#  ('called', 'the', 'Missile', 'Man', 'of', 'India', '.', 'He', 'was', 'a'),
#  ('the', 'Missile', 'Man', 'of', 'India', '.', 'He', 'was', 'a', 'famous'),
#  ('Missile',
#   'Man',
#   'of',
#   'India',
#   '.',
#   'He',
#   'was',
#   'a',
#   'famous',
#   'scientist'),
#  ('Man', 'of', 'India', '.', 'He', 'was', 'a', 'famous', 'scientist', '.'),
#  ('of', 'India', '.', 'He', 'was', 'a', 'famous', 'scientist', '.', 'He'),
#  ('India', '.', 'He', 'was', 'a', 'famous', 'scientist', '.', 'He', 'worked'),
#  ('.', 'He', 'was', 'a', 'famous', 'scientist', '.', 'He', 'worked', 'with'),
#  ('He',
#   'was',
#   'a',
#   'famous',
#   'scientist',
#   '.',
#   'He',
#   'worked',
#   'with',
#   'organizations'),
#  ('was',
#   'a',
#   'famous',
#   'scientist',
#   '.',
#   'He',
#   'worked',
#   'with',
#   'organizations',
#   'like'),
#  ('a',
#   'famous',
#   'scientist',
#   '.',
#   'He',
#   'worked',
#   'with',
#   'organizations',
#   'like',
#   'DRDO'),
#  ('famous',
#   'scientist',
#   '.',
#   'He',
#   'worked',
#   'with',
#   'organizations',
#   'like',
#   'DRDO',
#   '('),
#  ('scientist',
#   '.',
#   'He',
#   'worked',
#   'with',
#   'organizations',
#   'like',
#   'DRDO',
#   '(',
#   'Defense'),
#  ('.',
#   'He',
#   'worked',
#   'with',
#   'organizations',
#   'like',
#   'DRDO',
#   '(',
#   'Defense',
#   'Research'),
#  ('He',
#   'worked',
#   'with',
#   'organizations',
#   'like',
#   'DRDO',
#   '(',
#   'Defense',
#   'Research',
#   'and'),
#  ('worked',
#   'with',
#   'organizations',
#   'like',
#   'DRDO',
#   '(',
#   'Defense',
#   'Research',
#   'and',
#   'Development'),
#  ('with',
#   'organizations',
#   'like',
#   'DRDO',
#   '(',
#   'Defense',
#   'Research',
#   'and',
#   'Development',
#   'Organization'),
#  ('organizations',
#   'like',
#   'DRDO',
#   '(',
#   'Defense',
#   'Research',
#   'and',
#   'Development',
#   'Organization',
#   ')'),
#  ('like',
#   'DRDO',
#   '(',
#   'Defense',
#   'Research',
#   'and',
#   'Development',
#   'Organization',
#   ')',
#   'and'),
#  ('DRDO',
#   '(',
#   'Defense',
#   'Research',
#   'and',
#   'Development',
#   'Organization',
#   ')',
#   'and',
#   'ISRO'),
#  ('(',
#   'Defense',
#   'Research',
#   'and',
#   'Development',
#   'Organization',
#   ')',
#   'and',
#   'ISRO',
#   '('),
#  ('Defense',
#   'Research',
#   'and',
#   'Development',
#   'Organization',
#   ')',
#   'and',
#   'ISRO',
#   '(',
#   'Indian'),
#  ('Research',
#   'and',
#   'Development',
#   'Organization',
#   ')',
#   'and',
#   'ISRO',
#   '(',
#   'Indian',
#   'Space'),
#  ('and',
#   'Development',
#   'Organization',
#   ')',
#   'and',
#   'ISRO',
#   '(',
#   'Indian',
#   'Space',
#   'Research'),
#  ('Development',
#   'Organization',
#   ')',
#   'and',
#   'ISRO',
#   '(',
#   'Indian',
#   'Space',
#   'Research',
#   'Organization'),
#  ('Organization',
#   ')',
#   'and',
#   'ISRO',
#   '(',
#   'Indian',
#   'Space',
#   'Research',
#   'Organization',
#   ')'),
#  (')',
#   'and',
#   'ISRO',
#   '(',
#   'Indian',
#   'Space',
#   'Research',
#   'Organization',
#   ')',
#   '.'),
#  ('and',
#   'ISRO',
#   '(',
#   'Indian',
#   'Space',
#   'Research',
#   'Organization',
#   ')',
#   '.',
#   'He'),
#  ('ISRO',
#   '(',
#   'Indian',
#   'Space',
#   'Research',
#   'Organization',
#   ')',
#   '.',
#   'He',
#   'was'),
#  ('(',
#   'Indian',
#   'Space',
#   'Research',
#   'Organization',
#   ')',
#   '.',
#   'He',
#   'was',
#   'a'),
#  ('Indian',
#   'Space',
#   'Research',
#   'Organization',
#   ')',
#   '.',
#   'He',
#   'was',
#   'a',
#   'real'),
#  ('Space',
#   'Research',
#   'Organization',
#   ')',
#   '.',
#   'He',
#   'was',
#   'a',
#   'real',
#   'gem'),
#  ('Research', 'Organization', ')', '.', 'He', 'was', 'a', 'real', 'gem', 'of'),
#  ('Organization', ')', '.', 'He', 'was', 'a', 'real', 'gem', 'of', 'India'),
#  (')', '.', 'He', 'was', 'a', 'real', 'gem', 'of', 'India', '.'),
#  ('.', 'He', 'was', 'a', 'real', 'gem', 'of', 'India', '.', 'He'),
#  ('He', 'was', 'a', 'real', 'gem', 'of', 'India', '.', 'He', 'proved'),
#  ('was', 'a', 'real', 'gem', 'of', 'India', '.', 'He', 'proved', 'that'),
#  ('a', 'real', 'gem', 'of', 'India', '.', 'He', 'proved', 'that', 'with'),
#  ('real',
#   'gem',
#   'of',
#   'India',
#   '.',
#   'He',
#   'proved',
#   'that',
#   'with',
#   'determination'),
#  ('gem',
#   'of',
#   'India',
#   '.',
#   'He',
#   'proved',
#   'that',
#   'with',
#   'determination',
#   'and'),
#  ('of',
#   'India',
#   '.',
#   'He',
#   'proved',
#   'that',
#   'with',
#   'determination',
#   'and',
#   'hard'),
#  ('India',
#   '.',
#   'He',
#   'proved',
#   'that',
#   'with',
#   'determination',
#   'and',
#   'hard',
#   'work'),
#  ('.',
#   'He',
#   'proved',
#   'that',
#   'with',
#   'determination',
#   'and',
#   'hard',
#   'work',
#   'anything'),
#  ('He',
#   'proved',
#   'that',
#   'with',
#   'determination',
#   'and',
#   'hard',
#   'work',
#   'anything',
#   'can'),
#  ('proved',
#   'that',
#   'with',
#   'determination',
#   'and',
#   'hard',
#   'work',
#   'anything',
#   'can',
#   'be'),
#  ('that',
#   'with',
#   'determination',
#   'and',
#   'hard',
#   'work',
#   'anything',
#   'can',
#   'be',
#   'achieved'),
#  ('with',
#   'determination',
#   'and',
#   'hard',
#   'work',
#   'anything',
#   'can',
#   'be',
#   'achieved',
#   '.'),
#  ('determination',
#   'and',
#   'hard',
#   'work',
#   'anything',
#   'can',
#   'be',
#   'achieved',
#   '.',
#   'He'),
#  ('and', 'hard', 'work', 'anything', 'can', 'be', 'achieved', '.', 'He', 'is'),
#  ('hard', 'work', 'anything', 'can', 'be', 'achieved', '.', 'He', 'is', 'one'),
#  ('work', 'anything', 'can', 'be', 'achieved', '.', 'He', 'is', 'one', 'of'),
#  ('anything', 'can', 'be', 'achieved', '.', 'He', 'is', 'one', 'of', 'the'),
#  ('can', 'be', 'achieved', '.', 'He', 'is', 'one', 'of', 'the', 'many'),
#  ('be', 'achieved', '.', 'He', 'is', 'one', 'of', 'the', 'many', 'leaders'),
#  ('achieved', '.', 'He', 'is', 'one', 'of', 'the', 'many', 'leaders', 'in'),
#  ('.', 'He', 'is', 'one', 'of', 'the', 'many', 'leaders', 'in', 'India'),
#  ('He', 'is', 'one', 'of', 'the', 'many', 'leaders', 'in', 'India', 'who'),
#  ('is', 'one', 'of', 'the', 'many', 'leaders', 'in', 'India', 'who', 'has'),
#  ('one',
#   'of',
#   'the',
#   'many',
#   'leaders',
#   'in',
#   'India',
#   'who',
#   'has',
#   'plenty'),
#  ('of', 'the', 'many', 'leaders', 'in', 'India', 'who', 'has', 'plenty', 'of'),
#  ('the',
#   'many',
#   'leaders',
#   'in',
#   'India',
#   'who',
#   'has',
#   'plenty',
#   'of',
#   'admirers'),
#  ('many',
#   'leaders',
#   'in',
#   'India',
#   'who',
#   'has',
#   'plenty',
#   'of',
#   'admirers',
#   '.'),
#  ('leaders',
#   'in',
#   'India',
#   'who',
#   'has',
#   'plenty',
#   'of',
#   'admirers',
#   '.',
#   'He'),
#  ('in',
#   'India',
#   'who',
#   'has',
#   'plenty',
#   'of',
#   'admirers',
#   '.',
#   'He',
#   'served'),
#  ('India',
#   'who',
#   'has',
#   'plenty',
#   'of',
#   'admirers',
#   '.',
#   'He',
#   'served',
#   'the'),
#  ('who',
#   'has',
#   'plenty',
#   'of',
#   'admirers',
#   '.',
#   'He',
#   'served',
#   'the',
#   'nation'),
#  ('has',
#   'plenty',
#   'of',
#   'admirers',
#   '.',
#   'He',
#   'served',
#   'the',
#   'nation',
#   'for'),
#  ('plenty',
#   'of',
#   'admirers',
#   '.',
#   'He',
#   'served',
#   'the',
#   'nation',
#   'for',
#   'only'),
#  ('of',
#   'admirers',
#   '.',
#   'He',
#   'served',
#   'the',
#   'nation',
#   'for',
#   'only',
#   'one'),
#  ('admirers',
#   '.',
#   'He',
#   'served',
#   'the',
#   'nation',
#   'for',
#   'only',
#   'one',
#   'term'),
#  ('.', 'He', 'served', 'the', 'nation', 'for', 'only', 'one', 'term', 'and'),
#  ('He',
#   'served',
#   'the',
#   'nation',
#   'for',
#   'only',
#   'one',
#   'term',
#   'and',
#   'left'),
#  ('served',
#   'the',
#   'nation',
#   'for',
#   'only',
#   'one',
#   'term',
#   'and',
#   'left',
#   'us'),
#  ('the', 'nation', 'for', 'only', 'one', 'term', 'and', 'left', 'us', 'for'),
#  ('nation',
#   'for',
#   'only',
#   'one',
#   'term',
#   'and',
#   'left',
#   'us',
#   'for',
#   'always'),
#  ('for', 'only', 'one', 'term', 'and', 'left', 'us', 'for', 'always', 'on'),
#  ('only', 'one', 'term', 'and', 'left', 'us', 'for', 'always', 'on', '27'),
#  ('one', 'term', 'and', 'left', 'us', 'for', 'always', 'on', '27', 'July'),
#  ('term', 'and', 'left', 'us', 'for', 'always', 'on', '27', 'July', '2015'),
#  ('and', 'left', 'us', 'for', 'always', 'on', '27', 'July', '2015', 'due'),
#  ('left', 'us', 'for', 'always', 'on', '27', 'July', '2015', 'due', 'to'),
#  ('us', 'for', 'always', 'on', '27', 'July', '2015', 'due', 'to', 'cardiac'),
#  ('for',
#   'always',
#   'on',
#   '27',
#   'July',
#   '2015',
#   'due',
#   'to',
#   'cardiac',
#   'arrest'),
#  ('always', 'on', '27', 'July', '2015', 'due', 'to', 'cardiac', 'arrest', '.')]

# %%
string_bigrams = list(nltk.ngrams(sentence,4))
string_bigrams
# Out:
# [('Speech on APJ Abdul Kalam: Dr. APJ Abdul Kalam is not a new name.',
#   'He served India as the 11th president.',
#   'He was born on 15 October 1931 in Rameswaram, Tamil Nadu.',
#   'Because of his works in the field of science and especially missile and rockets,\n            he is also called the Missile Man of India.'),
#  ('He served India as the 11th president.',
#   'He was born on 15 October 1931 in Rameswaram, Tamil Nadu.',
#   'Because of his works in the field of science and especially missile and rockets,\n            he is also called the Missile Man of India.',
#   'He was a famous scientist.'),
#  ('He was born on 15 October 1931 in Rameswaram, Tamil Nadu.',
#   'Because of his works in the field of science and especially missile and rockets,\n            he is also called the Missile Man of India.',
#   'He was a famous scientist.',
#   'He worked with organizations like DRDO (Defense Research and Development Organization)\n            and ISRO (Indian Space Research Organization).'),
#  ('Because of his works in the field of science and especially missile and rockets,\n            he is also called the Missile Man of India.',
#   'He was a famous scientist.',
#   'He worked with organizations like DRDO (Defense Research and Development Organization)\n            and ISRO (Indian Space Research Organization).',
#   'He was a real gem of India.'),
#  ('He was a famous scientist.',
#   'He worked with organizations like DRDO (Defense Research and Development Organization)\n            and ISRO (Indian Space Research Organization).',
#   'He was a real gem of India.',
#   'He proved that with determination and hard work anything can be achieved.'),
#  ('He worked with organizations like DRDO (Defense Research and Development Organization)\n            and ISRO (Indian Space Research Organization).',
#   'He was a real gem of India.',
#   'He proved that with determination and hard work anything can be achieved.',
#   'He is one of the many leaders in India who has plenty of admirers.'),
#  ('He was a real gem of India.',
#   'He proved that with determination and hard work anything can be achieved.',
#   'He is one of the many leaders in India who has plenty of admirers.',
#   'He served the nation for only one term and left us for always on 27 July 2015 due to cardiac arrest.')]

# %%
string_bigrams = list(nltk.bigrams(sentence))
string_bigrams
# Out:
# [('Speech on APJ Abdul Kalam: Dr. APJ Abdul Kalam is not a new name.',
#   'He served India as the 11th president.'),
#  ('He served India as the 11th president.',
#   'He was born on 15 October 1931 in Rameswaram, Tamil Nadu.'),
#  ('He was born on 15 October 1931 in Rameswaram, Tamil Nadu.',
#   'Because of his works in the field of science and especially missile and rockets,\n            he is also called the Missile Man of India.'),
#  ('Because of his works in the field of science and especially missile and rockets,\n            he is also called the Missile Man of India.',
#   'He was a famous scientist.'),
#  ('He was a famous scientist.',
#   'He worked with organizations like DRDO (Defense Research and Development Organization)\n            and ISRO (Indian Space Research Organization).'),
#  ('He worked with organizations like DRDO (Defense Research and Development Organization)\n            and ISRO (Indian Space Research Organization).',
#   'He was a real gem of India.'),
#  ('He was a real gem of India.',
#   'He proved that with determination and hard work anything can be achieved.'),
#  ('He proved that with determination and hard work anything can be achieved.',
#   'He is one of the many leaders in India who has plenty of admirers.'),
#  ('He is one of the many leaders in India who has plenty of admirers.',
#   'He served the nation for only one term and left us for always on 27 July 2015 due to cardiac arrest.')]
